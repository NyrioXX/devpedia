# %% [markdown]
# # **Conceitos basicos**
#
# 1. **Variáveis e Tipos de Dados:**
#    - Em Python, você pode criar variáveis para armazenar dados. Os tipos de dados básicos incluem inteiros (`int`), números de ponto flutuante (`float`), strings (`str`), listas (`list`), tuplas (`tuple`), conjuntos (`set`), dicionários (`dict`) e booleanos (`bool`).
#
#    Exemplo:
#    ```python
#    int = 25
#    str = "João"
#    float = 1.75
#    bool = true
#    list = [1, 2, 3, 4, 5]
#    tuple = ("pera","abacaxi","morango") # tupla são listas imutaveis
#    dict = {"maria","felipe","joao"}
#    set = {"blade","shaolin","lin"} # conjuntos são dict com elementos unicos
#    ```
#
# 2. **Operadores:**
#    - Python suporta operadores aritméticos (+, -, *, /), operadores de comparação (==, !=, <, >), operadores lógicos (and, or, not), entre outros.
#
#    Exemplo:
#    ```python
#    resultado = 10 + 5
#    comparacao = (idade > 18) and (altura > 1.60)
#    ```
#
# 3. **Estruturas de Controle de Fluxo:**
#    - Python utiliza indentação para definir blocos de código. As estruturas de controle incluem `if`, `else`, `elif` para condicionais, e `for` e `while` para loops.
#
#    Exemplo:
#    ```python
#    if idade >= 18:
#        print("Você é maior de idade.")
#    else:
#        print("Você é menor de idade.")
#    ```
#
# 4. **Funções:**
#    - Funções são blocos de código reutilizáveis. Você pode criar funções com a palavra-chave `def`.
#
#    Exemplo:
#    ```python
#    def saudacao(nome):
#        print(f"Olá, {nome}!")
#
#    saudacao("Maria")
#    ```
#
# 5. **Listas e Iterações:**
#    - Listas são estruturas de dados que podem armazenar múltiplos itens. Iterações podem ser feitas usando `for` ou `while`.
#
#    Exemplo:
#    ```python
#    numeros = [1, 2, 3, 4, 5]
#    for num in numeros:
#        print(num)
#    ```
#
# 6. **Dicionários:**
#    - Dicionários são estruturas de dados que mapeiam chaves a valores.
#
#    Exemplo:
#    ```python
#    aluno = {"nome": "Ana", "idade": 20, "curso": "Ciência da Computação"}
#    print(aluno["nome"])
#    ```
